# %%
# Dependencies and setup
import pandas as pd
from numpy import cos, sin, arcsin, sqrt
from math import radians

# %%
# Load NYC January 2019 file.
jan_to_load = "201901-citibike-tripdata.csv.zip"

# %%
# Read data file and store into Pandas dataframe.
jan_df = pd.read_csv(jan_to_load, compression="zip")
jan_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender
# 0                  -73.970416   15839  Subscriber        1971       1
# 1                  -73.973442   32723  Subscriber        1964       1
# 2                  -73.958562   27451  Subscriber        1987       1
# 3                  -73.996430   21579  Subscriber        1990       1
# 4                  -73.987520   35379  Subscriber        1979       1
# ...                       ...     ...         ...         ...     ...
# 967282             -73.979453   19780  Subscriber        1978       2
# 967283             -73.985462   34365  Subscriber        1976       2
# 967284             -73.971115   25889  Subscriber        1977       1
# 967285             -73.975232   34649  Subscriber        1994       1
# 967286             -73.962408   17299  Subscriber        1979       1
#
# [967287 rows x 15 columns]

# %%
# Drop null values in start and end station ID columns. 
jan_df_drop_null = jan_df.dropna()
jan_df_drop_null
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender
# 0                  -73.970416   15839  Subscriber        1971       1
# 1                  -73.973442   32723  Subscriber        1964       1
# 2                  -73.958562   27451  Subscriber        1987       1
# 3                  -73.996430   21579  Subscriber        1990       1
# 4                  -73.987520   35379  Subscriber        1979       1
# ...                       ...     ...         ...         ...     ...
# 967282             -73.979453   19780  Subscriber        1978       2
# 967283             -73.985462   34365  Subscriber        1976       2
# 967284             -73.971115   25889  Subscriber        1977       1
# 967285             -73.975232   34649  Subscriber        1994       1
# 967286             -73.962408   17299  Subscriber        1979       1
#
# [967269 rows x 15 columns]

# %%
# Drop birth years 1886-1901.
# In 2019, the oldest person living in the U.S. was 114 years old.
jan_df_drop_null_and_birth_yrs = jan_df_drop_null[jan_df_drop_null["birth year"]>1901]
jan_df_drop_null_and_birth_yrs
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender
# 0                  -73.970416   15839  Subscriber        1971       1
# 1                  -73.973442   32723  Subscriber        1964       1
# 2                  -73.958562   27451  Subscriber        1987       1
# 3                  -73.996430   21579  Subscriber        1990       1
# 4                  -73.987520   35379  Subscriber        1979       1
# ...                       ...     ...         ...         ...     ...
# 967282             -73.979453   19780  Subscriber        1978       2
# 967283             -73.985462   34365  Subscriber        1976       2
# 967284             -73.971115   25889  Subscriber        1977       1
# 967285             -73.975232   34649  Subscriber        1994       1
# 967286             -73.962408   17299  Subscriber        1979       1
#
# [966499 rows x 15 columns]

# %%
# Calculate age and place in a new column in the jan_df_drop_null_and_birth_yrs dataframe.
jan_df_drop_null_and_birth_yrs["age"] = 2018 - jan_df_drop_null_and_birth_yrs["birth year"]
jan_df_drop_null_and_birth_yrs
# Out:
# C:\Users\ninap\AppData\Local\Temp/ipykernel_10696/3315753977.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_df_drop_null_and_birth_yrs["age"] = 2018 - jan_df_drop_null_and_birth_yrs["birth year"]
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender  age
# 0                  -73.970416   15839  Subscriber        1971       1   47
# 1                  -73.973442   32723  Subscriber        1964       1   54
# 2                  -73.958562   27451  Subscriber        1987       1   31
# 3                  -73.996430   21579  Subscriber        1990       1   28
# 4                  -73.987520   35379  Subscriber        1979       1   39
# ...                       ...     ...         ...         ...     ...  ...
# 967282             -73.979453   19780  Subscriber        1978       2   40
# 967283             -73.985462   34365  Subscriber        1976       2   42
# 967284             -73.971115   25889  Subscriber        1977       1   41
# 967285             -73.975232   34649  Subscriber        1994       1   24
# 967286             -73.962408   17299  Subscriber        1979       1   39
#
# [966499 rows x 16 columns]

# %%
# Calculate the average distance in miles for a bike trip.
def haversine(row):
    lon1 = row["start station longitude"]
    lat1 = row["start station latitude"]
    lon2 = row["end station longitude"]
    lat2 = row["end station latitude"]
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * arcsin(sqrt(a)) 
    km = 6367 * c
    return km

# %%
jan_df_drop_null_and_birth_yrs["trip distance km"] = jan_df_drop_null_and_birth_yrs.apply(lambda row: haversine(row), axis=1)
jan_df_drop_null_and_birth_yrs
# Out:
# C:\Users\ninap\AppData\Local\Temp/ipykernel_10696/2793568942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_df_drop_null_and_birth_yrs["trip distance km"] = jan_df_drop_null_and_birth_yrs.apply(lambda row: haversine(row), axis=1)
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender  age  \
# 0                  -73.970416   15839  Subscriber        1971       1   47
# 1                  -73.973442   32723  Subscriber        1964       1   54
# 2                  -73.958562   27451  Subscriber        1987       1   31
# 3                  -73.996430   21579  Subscriber        1990       1   28
# 4                  -73.987520   35379  Subscriber        1979       1   39
# ...                       ...     ...         ...         ...     ...  ...
# 967282             -73.979453   19780  Subscriber        1978       2   40
# 967283             -73.985462   34365  Subscriber        1976       2   42
# 967284             -73.971115   25889  Subscriber        1977       1   41
# 967285             -73.975232   34649  Subscriber        1994       1   24
# 967286             -73.962408   17299  Subscriber        1979       1   39
#
#         trip distance km
# 0               1.065821
# 1               0.577360
# 2               2.032736
# 3               1.402486
# 4               1.315246
# ...                  ...
# 967282          0.925856
# 967283          1.016765
# 967284          0.794507
# 967285          0.791014
# 967286          1.452366
#
# [966499 rows x 17 columns]

# %%
# Convert the "trip distance" column from km to mi. 
jan_df_drop_null_and_birth_yrs["trip distance mi"] = jan_df_drop_null_and_birth_yrs["trip distance km"] * 0.621371
jan_df_drop_null_and_birth_yrs
# Out:
# C:\Users\ninap\AppData\Local\Temp/ipykernel_10696/404324398.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_df_drop_null_and_birth_yrs["trip distance mi"] = jan_df_drop_null_and_birth_yrs["trip distance km"] * 0.621371
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender  age  \
# 0                  -73.970416   15839  Subscriber        1971       1   47
# 1                  -73.973442   32723  Subscriber        1964       1   54
# 2                  -73.958562   27451  Subscriber        1987       1   31
# 3                  -73.996430   21579  Subscriber        1990       1   28
# 4                  -73.987520   35379  Subscriber        1979       1   39
# ...                       ...     ...         ...         ...     ...  ...
# 967282             -73.979453   19780  Subscriber        1978       2   40
# 967283             -73.985462   34365  Subscriber        1976       2   42
# 967284             -73.971115   25889  Subscriber        1977       1   41
# 967285             -73.975232   34649  Subscriber        1994       1   24
# 967286             -73.962408   17299  Subscriber        1979       1   39
#
#         trip distance km  trip distance mi
# 0               1.065821          0.662270
# 1               0.577360          0.358754
# 2               2.032736          1.263083
# 3               1.402486          0.871464
# 4               1.315246          0.817256
# ...                  ...               ...
# 967282          0.925856          0.575300
# 967283          1.016765          0.631788
# 967284          0.794507          0.493684
# 967285          0.791014          0.491513
# 967286          1.452366          0.902458
#
# [966499 rows x 18 columns]

# %%
# Drop trip distances equivalent to zero. 
jan_df_drop_null_and_birth_yrs = jan_df_drop_null_and_birth_yrs.loc[jan_df_drop_null_and_birth_yrs["trip distance mi"] !=0]
jan_df_drop_null_and_birth_yrs
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender  age  \
# 0                  -73.970416   15839  Subscriber        1971       1   47
# 1                  -73.973442   32723  Subscriber        1964       1   54
# 2                  -73.958562   27451  Subscriber        1987       1   31
# 3                  -73.996430   21579  Subscriber        1990       1   28
# 4                  -73.987520   35379  Subscriber        1979       1   39
# ...                       ...     ...         ...         ...     ...  ...
# 967282             -73.979453   19780  Subscriber        1978       2   40
# 967283             -73.985462   34365  Subscriber        1976       2   42
# 967284             -73.971115   25889  Subscriber        1977       1   41
# 967285             -73.975232   34649  Subscriber        1994       1   24
# 967286             -73.962408   17299  Subscriber        1979       1   39
#
#         trip distance km  trip distance mi
# 0               1.065821          0.662270
# 1               0.577360          0.358754
# 2               2.032736          1.263083
# 3               1.402486          0.871464
# 4               1.315246          0.817256
# ...                  ...               ...
# 967282          0.925856          0.575300
# 967283          1.016765          0.631788
# 967284          0.794507          0.493684
# 967285          0.791014          0.491513
# 967286          1.452366          0.902458
#
# [951003 rows x 18 columns]

# %%
# Add a column that converts trip duration from seconds in the first column to minutes. 
jan_df_drop_null_and_birth_yrs["tripduration minutes"] = jan_df_drop_null_and_birth_yrs["tripduration"]/60
jan_df_drop_null_and_birth_yrs
# Out:
# C:\Users\ninap\AppData\Local\Temp/ipykernel_10696/820013789.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_df_drop_null_and_birth_yrs["tripduration minutes"] = jan_df_drop_null_and_birth_yrs["tripduration"]/60
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# 0                 3160.0  Central Park West & W 76 St               40.778968
# 1                  519.0        Pershing Square North               40.751873
# 2                 3171.0      Amsterdam Ave & W 82 St               40.785247
# 3                  504.0              1 Ave & E 16 St               40.732219
# 4                  229.0               Great Jones St               40.727434
# ...                  ...                          ...                     ...
# 967282            3354.0    3 St & Prospect Park West               40.668132
# 967283            3354.0    3 St & Prospect Park West               40.668132
# 967284            3354.0    3 St & Prospect Park West               40.668132
# 967285            3354.0    3 St & Prospect Park West               40.668132
# 967286            3354.0    3 St & Prospect Park West               40.668132
#
#         start station longitude  end station id  \
# 0                    -73.973747          3283.0
# 1                    -73.977706           518.0
# 2                    -73.976673          3154.0
# 3                    -73.981656          3709.0
# 4                    -73.993790           503.0
# ...                         ...             ...
# 967282               -73.973638          3423.0
# 967283               -73.973638          3313.0
# 967284               -73.973638          3418.0
# 967285               -73.973638          3346.0
# 967286               -73.973638          3549.0
#
#                        end station name  end station latitude  \
# 0                W 89 St & Columbus Ave             40.788221
# 1                       E 39 St & 2 Ave             40.747804
# 2                       E 77 St & 3 Ave             40.773142
# 3                       W 15 St & 6 Ave             40.738046
# 4                    E 20 St & Park Ave             40.738274
# ...                                 ...                   ...
# 967282  West Drive & Prospect Park West             40.661063
# 967283                    6 Ave & 12 St             40.666318
# 967284     Plaza St West & Flatbush Ave             40.675021
# 967285              Berkeley Pl & 7 Ave             40.675147
# 967286            Grand Ave & Bergen St             40.678045
#
#         end station longitude  bikeid    usertype  birth year  gender  age  \
# 0                  -73.970416   15839  Subscriber        1971       1   47
# 1                  -73.973442   32723  Subscriber        1964       1   54
# 2                  -73.958562   27451  Subscriber        1987       1   31
# 3                  -73.996430   21579  Subscriber        1990       1   28
# 4                  -73.987520   35379  Subscriber        1979       1   39
# ...                       ...     ...         ...         ...     ...  ...
# 967282             -73.979453   19780  Subscriber        1978       2   40
# 967283             -73.985462   34365  Subscriber        1976       2   42
# 967284             -73.971115   25889  Subscriber        1977       1   41
# 967285             -73.975232   34649  Subscriber        1994       1   24
# 967286             -73.962408   17299  Subscriber        1979       1   39
#
#         trip distance km  trip distance mi  tripduration minutes
# 0               1.065821          0.662270              5.333333
# 1               0.577360          0.358754              5.266667
# 2               2.032736          1.263083              9.850000
# 3               1.402486          0.871464             45.316667
# 4               1.315246          0.817256              5.050000
# ...                  ...               ...                   ...
# 967282          0.925856          0.575300              4.850000
# 967283          1.016765          0.631788              7.283333
# 967284          0.794507          0.493684              2.883333
# 967285          0.791014          0.491513              4.066667
# 967286          1.452366          0.902458              6.450000
#
# [951003 rows x 19 columns]

# %%
# Calculate the average trip duration in minutes.
jan_df_drop_null_and_birth_yrs["tripduration minutes"].mean()
# Out:
# 12.685556880472234

# %%
# Calculate how many trips were taken in January.
jan_df_drop_null_and_birth_yrs["tripduration"].count()
# Out:
# 951003

# %%
# Calculate the average age of the consumer. 
jan_df_drop_null_and_birth_yrs["age"].mean()
# Out:
# 39.08131414937703

# %%
# Calculate average trip distance
jan_df_drop_null_and_birth_yrs["trip distance mi"].mean()
# Out:
# 0.9941833838060975

# %%
# Load new dataframe as a .csv
compression_opts = dict(method="zip", archive_name="clean_201901-citibike-tripdata.csv")
jan_df_drop_null_and_birth_yrs.to_csv("clean_201901-citibike-tripdata.zip", index=False, compression=compression_opts)
